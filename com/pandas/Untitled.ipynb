# %%
import pandas as pd
df = pd.read_csv("debts.csv")

# %%
print(df)
# Out:
#                                     Date                       Security Code  \
# 16 Mar 2020 1710AHPCL20     INE990I07014   ALAKNANDA HYDRO POWER COMPANY LTD
# 28 May 2020 10KBJNL2024     INE990D07296   KRISHNA BHAGYA JALA NIGAM LIMITED
# 27 Apr 2020 0KOTAKINV21     INE975F07GR2  KOTAK MAHINDRA INVESTMENTS LIMITED
# 18 Mar 2020 863KMIL21       INE975F07GQ4  KOTAK MAHINDRA INVESTMENTS LIMITED
#             851KMIL21       INE975F07GN1  KOTAK MAHINDRA INVESTMENTS LIMITED
# ...                                  ...                                 ...
# 05 Feb 2020 832RJIO21                  -                                   -
# 06 Mar 2020 870BOB99                   -                                   -
# 24 Apr 2020 905UBOI27                  -                                   -
# 03 Feb 2020 925RJIL2024                -                                   -
# 14 May 2020 995SYNDBNKPERP             -                                   -
#
# ...

# %%
df.columns 

print(df['Date'])
# Out:
# 16 Mar 2020  1710AHPCL20       INE990I07014
# 28 May 2020  10KBJNL2024       INE990D07296
# 27 Apr 2020  0KOTAKINV21       INE975F07GR2
# 18 Mar 2020  863KMIL21         INE975F07GQ4
#              851KMIL21         INE975F07GN1
#                                    ...
# 05 Feb 2020  832RJIO21                    -
# 06 Mar 2020  870BOB99                     -
# 24 Apr 2020  905UBOI27                    -
# 03 Feb 2020  925RJIL2024                  -
# 14 May 2020  995SYNDBNKPERP               -
# Name: Date, Length: 823, dtype: object
#                                  Date                       Security Code  \
# 16 Mar 2020 1710AHPCL20  INE990I07014   ALAKNANDA HYDRO POWER COMPANY LTD
# 28 May 2020 10KBJNL2024  INE990D07296   KRISHNA BHAGYA JALA NIGAM LIMITED
# 27 Apr 2020 0KOTAKINV21  INE975F07GR2  KOTAK MAHINDRA INVESTMENTS LIMITED
# 18 Mar 2020 863KMIL21    INE975F07GQ4  KOTAK MAHINDRA INVESTMENTS LIMITED
#
# ...

# %%
print(df.head(1))
# Out:
#                                  Date                      Security Code  \
# 16 Mar 2020 1710AHPCL20  INE990I07014  ALAKNANDA HYDRO POWER COMPANY LTD
#
#                          ISIN No Issuer Name  Coupon(%)  Maturity Date  \
# 16 Mar 2020 1710AHPCL20     17.1  26/03/2020   106.5974          106.6
#
#                              LTP  Weighted Average- Price  \
# 16 Mar 2020 1710AHPCL20  17.1000                  13600.0
#
#                          Weighted Average- Yield  Turnover in Lakhs  \
# 16 Mar 2020 1710AHPCL20                        1                NaN
#
#                          No.Of Trades  Unnamed: 11
# 16 Mar 2020 1710AHPCL20           NaN          NaN

# %%
for index, row in df.iterrows():
    print(index, row[1])
# Out:
# ('16 Mar 2020', '1710AHPCL20') Date                                            INE990I07014
# Security Code              ALAKNANDA HYDRO POWER COMPANY LTD
# ISIN No                                                 17.1
# Issuer Name                                       26/03/2020
# Coupon(%)                                           106.5974
# Maturity Date                                          106.6
# LTP                                                  17.1000
# Weighted Average- Price                              13600.0
# Weighted Average- Yield                                    1
# Turnover in Lakhs                                        NaN
# No.Of Trades                                             NaN
# Unnamed: 11                                              NaN
# Name: (16 Mar 2020, 1710AHPCL20), dtype: object
# ('28 May 2020', '10KBJNL2024') Date                                            INE990D07296
# Security Code              KRISHNA BHAGYA JALA NIGAM LIMITED
# ...
